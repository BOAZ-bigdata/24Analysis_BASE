# %% [markdown]
# # 📖 딥러닝 모델의 Inductive Bias & NSMC 감정 분석 실습
#
# ## ✅ **TODO: 과제 1 - Inductive Bias 탐구**
# - [ ] FC Layer, RNN, LSTM, Attention의 Inductive Bias 조사
# - [ ] 개인의 해석을 정리하여 기입
#
# ---
#
# ## ✅ **TODO: 과제 2 - NSMC 감정 분석 실습** (❗빈칸 채우기 실습 포함 )
# - [ ] NSMC 데이터 전처리 (토큰화, 어휘 사전 생성)
# - [ ] RNN, LSTM, Attention 모델 구현 **(빈칸 채우기!)**
# - [ ] 모델 학습 및 평가 (정확도 비교, Confusion Matrix 분석)
# - [ ] 사용자 입력 문장 감정 분석
#
# 📌 **Colab 실행 시 GPU (`T4`) 사용 권장!**
#
#
# ---
# ---

# %% [markdown]
# # 📖 과제 1 : FC Layer, RNN, LSTM, Attention의 Inductive Bias 탐구
#
# ## 📌 과제 개요
# 이 과제에서는 딥러닝에서 자주 사용되는 **Fully Connected (FC) Layer, RNN, LSTM, Attention**의 **Inductive Bias**를 비교·탐구합니다.
# Inductive Bias란 **모델이 학습할 때 선호하는 패턴이나 추론 방식의 특성을 의미**하며, 서로 다른 신경망 구조에서 어떻게 다르게 나타나는지 분석하는 것이 목표입니다.
#
#
#
# ## 📂  과제 요구사항
#
# ### 📌 모델별 Inductive Bias 개념 조사
# 각 모델이 가지고 있는 **Inductive Bias**에 대해 조사하고, **이론적 배경을 정리**하세요.
# 다음 질문에 대한 답변을 정리하세요.

# %% [markdown]
# **FC Layer**: Fully Connected Layer는 어떤 inductive bias를 가지며, 어떤 패턴을 학습하는가?
#
# 답변 : Machine learning에서는 어떤 목표(target)를 달성(예측, 분류, 군집화,  등등...)하기 위해 데이터(feature)를 기반으로 학습할 수 있는 알고리즘 구축을 목표로 하고, 이를 위해 제한된 입력이 주어지고 그에 따른 출력이 만들어 지는데. 이 출력이 얼마나 목표에 부합하는지를 따져 학습을 하는데, 훈련 데이터를 넘어 다른 데이터에 대해서도 일반화할 수 있는 능력을 가진 모든 기계 학습 알고리즘에는 어떤 유형의 Inductive Bias가 존재하는데, 이는 모델이 목표 함수를 학습하고 훈련 데이터를 넘어 일반화하기 위해 만든 의도적인 bias(편차)이다. 즉 위에서 말한데로 일반적으로 이 모델이 볼 데이터가 가질것이라고 가정하는 패턴이나 이 모델이 추론을 하는 방식을 의미한다. 그에 따라 fc layer의 경우는 inductive bias가 없다 혹은 약하다고 할 수 있다. 이게 무슨 의미냐 하면 fc layer의 경우에는 따로 선호하는 패턴의 데이터가 없다, 혹은 추론하는 방식에 있어서 특별한 가정이 필요없다는 뜻이다. fc layer의 경우는 이름 그대로 모든 input이 모든 output에 영향을 동등하게 준다. 여기서 동등하게 라는 것은 가중치의 크고 작음을 의미하는 것이 아니라. 어떤 input이더라도 가중치와 곱해져 선형결합되고 나서 activation function을 거쳐 output이 되는데 이때 가중치가 0 이거나 activation function에 따라 0의 output이 나올 수도 있지만 이것은 영향을 안준게 아니라 0이라는 영향을 준것이라는 것을 의미한다. 즉 모든 input이 output을 형성하는데 동등한 영향을 준다. input의 어떠한 특성이 있어서 그 특성에 따라 output에 가해지는 영향이 다르지 않다는 뜻이다.

# %% [markdown]
# **RNN**: 순환 구조가 inductive bias에 어떤 영향을 미치는가?
#
# 답변 :RNN의 순환 구조는 이전 시점의 은닉 상태(hidden state)를 다음 시점으로 전달하여 과거 정보를 현재 예측에 반영한다. 이는 시계열 데이터나 순차적 데이터에 존재하는 시간적 흐름(순서에 의한 변동)을 반영하게 inductive bias를 설정한 것과 같다. 이를 짧게 sequentiality라고 한다. 그리고 이로 인해 파생되는 효과가 한 가지 더 있는데 순환구조로 rnn은 동일한 가중치가 곱해지는 형태이기 때문에 역전파 과정에서 기울기 소실이 일어나기도 한다. 이러한 특성 때문에 시간적 locality를 갖는다고 할 수도 있다. 무슨 의미냐면 시간적으로 더 먼 정보는 현재의 예측에 대해서 덜 반영이 된다는 것이다. 이러한 문제때문에 sequential데이터의 길이가 길어지면 성능이 떨어지기도 한다.

# %% [markdown]
# **LSTM**: 장기 의존성 문제를 해결하기 위해 어떤 inductive bias가 추가되는가?
# 답변 :
# ![image.png](attachment:image.png)
#
# lstm은 장기 의존성 문제를 해결하기 위해 게이트 메커니즘을 추가했다. 하나의 셀이라는 단위 안에 입력 게이트, 삭제 게이트, 출력 게이트 여러개의 게이트를 만들어 cell state를 업데이트 하는데 이용하는데 새로 들어오는 정보 중 어떤 것들을 cell state에 저장할 것인지, 이전 단계로부터 어떤 정보를 버릴 것인지, 그리고 출력으로 내보낼 은닉상태를 결정하는 게이트이다. 이 세개의 게이트를 이용하는데 cell state가 바로 장기 의존성에서의 핵심이라고 할 수 있다. cell state는 hidden state와는 다르다 hidden state는 비유하자면 단기 기억이고 cell state가 장기기억인거다. 이에 대해서 inductive bias가 뭐냐! 라고 얘기 한다면 추론 방식의 특징은 cell state라는 시퀸스의 전체적인 맥락을 요약하는 상태가 시퀸스의 처음부터 끝까지 매 시점마다 게이트들을 거치며 계산된 값과 간단한 연산만을 거쳐서 gradient vanishing을 방지하면서 중요한 정보가 쭉 이어져서 업데이트 되는 상태를 장기 기억으로써 이용한다는 거다. 더 짧게 요약하면 게이트 메커니즘과 cell state를 통한 정보의 선택적 보존으로 장기기억을 더 잘 할 수 있다는 것이다.

# %% [markdown]
# **Attention**: 문장 내 특정 단어에 집중하는 Attention 메커니즘의 inductive bias는 어떤 특징이 있는가?
#
# 답변 : Attention은 입력의 모든! 요소를 비교하며, 중요한 요소에 더 높은 가중치를 할당하는 메커니즘입니다. 이를 통해 모델은 어떤 정보가 중요한지 전체적으로! 학습할 수 있는 inductive bias를 갖는다. 짧게 이야기 하면 Attention 기반의 모델이 가지는 inductive bias는 contextual relaitionships과 global dependencies다. 맥락적인 관계와 전체적인 중요도를 잘 반영하여 추론을 한다는 거다. Transformer에서 positional embedding은 모델에게 토큰의 절대적인 위치, 상대적인 위치 및 위치가 조금 변해도 불변인 관계를 인지하게 한다. 그리고 attention score를 계산한다는 건 특정 입력 이전과 이후의 입력들에 대해 모두 비교해서 계산하므로 특정 입력이 중요하다는 것을 잘 잡아내는데 그게 바로 앞의 것이 아니라 뒤의 토큰에 대해서도, 입력 전체에 대해서 계산하는 것이기 때문에 전체적으로 반영을 한다는 거다. 그래서 transformer 모델은 CNN이나 RNN기반 모델보다 inductive bias가 모자라다는 이야기가 있는데 이게 무슨 말이냐면 CNN이나 RNN은 입력데이터의 내부적 특징을 반영을 한다는 거다. 입력이 어떠한 특성을 가지고 있을거다 그러니까 이런 방법으로 탐색을 할거다! 라고 한다는 거다. 그러면 attention도 그렇지 않나? 를 생각하지만 특정 단어에 집중하게 되는 과정이 학습인데 애초에 attention은 처음부터 전체적으로 보면서 집중할 부분을 끌어내는 거다. 구체적인 예시로 비교해 보자면 CNN은 입력에서 지역적인 값들을 가지고 그 다음 상위 정보를 산출해 낸다! 라는 inductive bias가 있다. 그런데 transformer는 처음부터 전역적인 정보를 전부 다 보면서 이끌어내겠다! 라는거다. 즉 모든 정보를 다 동등하게 일단 보고 시작하겠다! 라는거다. 일단 입력의 내부적 특징 따위는 일단 필요없고 전체적으로 보면서 한땀한땀 특징을 꺼내오겠다는 거다. 그러나 RNN이나 CNN보다는 확실히 약하다고 볼 수 있다. RNN처럼 입력을 순서대로 처리하는게 아니라 입력의 시간적 정보를 가정하는 것도 아니고 CNN처럼 특정 부분을 쪼개서 보는 것도 아니라 지역적 정보를 가정하는 것도 아니다. 다만 결과로서 지역적 중요도를 뽑아내기도 하고 입력의 순서가 바뀌어도 중요도를 뽑아내기도 하고 그나마 positional embedding이라도 해서 순서적 정보를 추가 해주기도 했다. 그리고 contextual relashionship을 보니까 아무런 내부 정보가 없다고 가정하고 진짜로 모두 동등하게 보는건 아니다. 그래서 fc layer보다는 inductive bias가 있긴 하다. 그래서 inductive bias가 적으면 뭐가 다르냐? inductive bias가 약하면 처음 보는 데이터가 들어왔을 때 성능이 떨어진다는 거다. 그래서 transformer모델이 그렇게 데이터의 양이 많아야 한다는 거다.

# %% [markdown]
# ---

# %% [markdown]
# # 📖 과제 2 : 네이버 영화 리뷰 감정 분석 (NSMC) 실습
#
# ## 📌 1. 실습 개요
# 이 실습에서는 **네이버 영화 리뷰 감정 분석 데이터(NSMC)**를 사용하여 텍스트 감정을 분류하는 **딥러닝 모델(RNN, LSTM, RNN+Attention)**을 학습합니다.
# 각 모델의 성능을 비교하고, **사용자 입력 문장에 대한 감정 예측**을 수행합니다.
#
#
# ## 🎯 2. 실습 목표
# ✔ 감정 분석을 위한 데이터 전처리 및 모델 학습 이해
# ✔ RNN, LSTM, Attention을 활용한 감정 분석 모델 구현 및 성능 비교
# ✔ 학습한 모델이 실제 문장을 어떻게 분류하는지 확인
#
# ### GPU 사용 권장! (ex, colab의 T4)

# %%
############################
# 0. 기본 설치 (Colab 환경)
############################

# Colab 등에서 한국어 형태소 분석기 사용 위해 konlpy 설치

# !pip install konlpy
# Out:
# Requirement already satisfied: konlpy in /usr/local/lib/python3.11/dist-packages (0.6.0)
# Requirement already satisfied: JPype1>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from konlpy) (1.5.2)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.11/dist-packages (from konlpy) (5.3.0)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.11/dist-packages (from konlpy) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from JPype1>=0.7.0->konlpy) (24.2)

# %%
############################
# 1. 라이브러리 임포트
############################

import sys
import os
import urllib.request

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import confusion_matrix, accuracy_score
from torch.utils.data import Dataset, DataLoader

# GPU 사용 가능 여부
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# 한국어 형태소 분석기 (예: Okt 사용)
from konlpy.tag import Okt
okt = Okt()
# Out:
# Using device: cuda

# %%
############################
# 2. NSMC 데이터 다운로드
############################

# ratings_train.txt, ratings_test.txt 파일이 없다면 다운로드
# (Colab 환경에서 예시)
if not os.path.isfile("ratings_train.txt"):
    url_train = "https://raw.githubusercontent.com/e9t/nsmc/master/ratings_train.txt"
    urllib.request.urlretrieve(url_train, "ratings_train.txt")

if not os.path.isfile("ratings_test.txt"):
    url_test = "https://raw.githubusercontent.com/e9t/nsmc/master/ratings_test.txt"
    urllib.request.urlretrieve(url_test, "ratings_test.txt")

print("NSMC 데이터 다운로드 완료")
# Out:
# NSMC 데이터 다운로드 완료

# %%
############################
# 3. 데이터 로드 및 전처리
############################

def load_data(filepath):
    """
    ratings_train.txt / ratings_test.txt 파일을 불러와서
    [text, label] 형태의 리스트를 반환
    """
    data = []
    with open(filepath, 'r', encoding='utf-8') as f:
        next(f)  # 헤더 건너뛰기
        for line in f:
            id_, text, label = line.strip().split('\t')
            if text == "":  # 공백 리뷰 제거
                continue
            data.append((text, int(label)))
    return data

train_data_raw = load_data("ratings_train.txt")
test_data_raw = load_data("ratings_test.txt")

print("훈련 데이터 개수:", len(train_data_raw))
print("테스트 데이터 개수:", len(test_data_raw))

# 데이터 샘플 확인
print("\n첫 번째 훈련 샘플:", train_data_raw[0])
# Out:
# 훈련 데이터 개수: 149995
# 테스트 데이터 개수: 49997
#
# 첫 번째 훈련 샘플: ('아 더빙.. 진짜 짜증나네요 목소리', 0)

# %%
############################
# 3-1. 형태소 분석 & 토큰화
############################

def tokenize(text):
    """
    간단히 Okt 형태소 분석기로 명사, 동사 등 단어 단위 토큰화 예시.
    필요에 따라 불용어 제거 등의 추가 처리가 가능.
    """
    # 예시: 불필요한 기호 제거 (정규 표현식 등)
    # 여기서는 간단히 한글, 영문, 숫자, 공백, 일부 문장부호만 남긴다고 가정
    import re
    text = re.sub(r"[^가-힣0-9a-zA-Z\s?!.,]", "", text)

    # 형태소 분석(Okt)
    # 이 예시에선 그냥 morphemes만 추출
    tokens = okt.morphs(text.strip())
    return tokens

# 간단 테스트
sample_text = train_data_raw[0][0]
print("원문:", sample_text)
print("토큰화 결과:", tokenize(sample_text))
# Out:
# 원문: 아 더빙.. 진짜 짜증나네요 목소리
# 토큰화 결과: ['아', '더빙', '..', '진짜', '짜증나네요', '목소리']

# %%
############################
# 3-2. 어휘 사전(Vocabulary) 생성
############################

from collections import defaultdict

# 매우 큰 데이터를 모두 사용할 경우 시간이 오래 걸릴 수 있으므로,
# 우선 "일부" 데이터(예: 상위 N개)만 사용해 시범실습할 수도 있습니다.
# 필요시 full_data = train_data_raw 로 변경하세요.
N = 20000  # 시범으로 2만 개만 사용할 경우
full_data = train_data_raw[:N]

word_freq = defaultdict(int)

for text, label in full_data:
    tokens = tokenize(text)
    for tok in tokens:
        word_freq[tok] += 1

# 사용 빈도가 낮은 단어는 제외 (예: 3회 미만)
min_freq = 3
vocab = ["<pad>", "<unk>"]
for w, f in word_freq.items():
    if f >= min_freq:
        vocab.append(w)

word2idx = {w: i for i, w in enumerate(vocab)}
print("단어 사전 크기:", len(vocab))

def text_to_ids(text, word2idx):
    tokens = tokenize(text)
    ids = []
    for tok in tokens:
        ids.append(word2idx.get(tok, word2idx["<unk>"]))
    return ids
# Out:
# 단어 사전 크기: 8845

# %%
############################
# 4. Dataset 및 DataLoader 구성
############################

# 최대 문장 길이(패딩을 위한). 너무 크게 잡으면 메모리 사용량 증가
max_len = 30

def pad_sequences(seq, max_len):
    """
    입력된 seq (List of token ids)에 대해
    max_len만큼 뒤를 <pad> 토큰으로 채워넣거나 자르는 함수
    """
    if len(seq) < max_len:
        seq = seq + [word2idx["<pad>"]] * (max_len - len(seq))
    else:
        seq = seq[:max_len]
    return seq

class NSMCDataset(Dataset):
    def __init__(self, data, word2idx, max_len=30):
        self.data = data
        self.word2idx = word2idx
        self.max_len = max_len

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        text, label = self.data[idx]
        token_ids = text_to_ids(text, self.word2idx)
        token_ids = pad_sequences(token_ids, self.max_len)
        return torch.LongTensor(token_ids), torch.LongTensor([label])

# 실제로는 전 데이터 쓰려면 full_data = train_data_raw, etc.
# 여기서는 위에서 N=20000으로 제한한 데이터 사용 (시간 단축용)
train_dataset = NSMCDataset(full_data, word2idx, max_len=max_len)
test_dataset = NSMCDataset(test_data_raw, word2idx, max_len=max_len)

batch_size = 64
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

print(f"훈련 배치 개수: {len(train_loader)}")
print(f"테스트 배치 개수: {len(test_loader)}")
# Out:
# 훈련 배치 개수: 313
# 테스트 배치 개수: 782

# %%
############################
# 4. Dataset 및 DataLoader 구성
############################

# 최대 문장 길이(패딩을 위한). 너무 크게 잡으면 메모리 사용량 증가
max_len = 30

def pad_sequences(seq, max_len):
    """
    입력된 seq (List of token ids)에 대해
    max_len만큼 뒤를 <pad> 토큰으로 채워넣거나 자르는 함수
    """
    if len(seq) < max_len:
        seq = seq + [word2idx["<pad>"]] * (max_len - len(seq))
    else:
        seq = seq[:max_len]
    return seq

class NSMCDataset(Dataset):
    def __init__(self, data, word2idx, max_len=30):
        self.data = data
        self.word2idx = word2idx
        self.max_len = max_len

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        text, label = self.data[idx]
        token_ids = text_to_ids(text, self.word2idx)
        token_ids = pad_sequences(token_ids, self.max_len)
        return torch.LongTensor(token_ids), torch.LongTensor([label])

# 실제로는 전 데이터 쓰려면 full_data = train_data_raw, etc.
# 여기서는 위에서 N=20000으로 제한한 데이터 사용 (시간 단축용)
train_dataset = NSMCDataset(full_data, word2idx, max_len=max_len)
test_dataset = NSMCDataset(test_data_raw, word2idx, max_len=max_len)

batch_size = 64
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

print(f"훈련 배치 개수: {len(train_loader)}")
print(f"테스트 배치 개수: {len(test_loader)}")
# Out:
# 훈련 배치 개수: 313
# 테스트 배치 개수: 782

# %%
############################
# 5. 모델 정의
#   5-1) RNN Classifier
############################

class RNNClassifier(nn.Module):
    def __init__(self, vocab_size, embed_dim, hidden_dim, num_classes=2):
        super(RNNClassifier, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embed_dim)
        self.rnn = nn.RNN(embed_dim,hidden_dim, batch_first=True)  # (힌트: 입력 차원은 단어 임베딩 차원, 은닉 상태 차원은 hidden_dim)
        self.fc = nn.Linear(hidden_dim, num_classes)  # (힌트: 마지막 은닉 상태 크기와 출력 클래스 개수)

    def forward(self, x):
        # x shape: (batch, seq_len)
        embedded = self.embedding(x)  # (batch, seq_len, embed_dim)
        output, hidden = self.rnn(embedded)  # (힌트: RNN의 입력은 임베딩된 단어 벡터)
        last_hidden = hidden[0]  # (힌트: RNN의 마지막 은닉 상태를 가져오기, 0번째 인덱스 사용)
        logits = self.fc(last_hidden)  # (힌트: 최종 은닉 상태를 FC Layer에 통과시켜 감정 예측)
        return logits

############################
#   5-2) LSTM Classifier
############################

class LSTMClassifier(nn.Module):
    def __init__(self, vocab_size, embed_dim, hidden_dim, num_classes=2):
        super(LSTMClassifier, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embed_dim)  # (단어 사전 크기, 임베딩 차원)
        self.lstm = nn.LSTM(embed_dim, hidden_dim, batch_first=True)  # (입력 차원: embed_dim, 출력 차원: hidden_dim)
        self.fc = nn.Linear(hidden_dim, num_classes)  # (은닉 상태 차원, 출력 클래스 개수)

    def forward(self, x):
        embedded = self.embedding(x)
        output, (hidden, cell) = self.lstm(embedded)  # (LSTM의 출력과 은닉 상태)
        last_hidden = hidden[0]  # (LSTM의 마지막 hidden state 사용, 0번째 인덱스)
        logits = self.fc(last_hidden)  # (마지막 은닉 상태를 FC Layer에 통과시켜 예측)
        return logits

############################
#   5-3) RNN + Attention
############################

class RNNWithAttention(nn.Module):
    def __init__(self, vocab_size, embed_dim, hidden_dim, num_classes=2):
        super(RNNWithAttention, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embed_dim)  # (단어 사전 크기, 임베딩 차원)
        self.rnn = nn.RNN(embed_dim, hidden_dim, batch_first=True)  # (RNN의 입력 차원은 embed_dim, 출력 차원은 hidden_dim)
        self.attn_fc = nn.Linear(hidden_dim, 1)  # (attention 가중치를 학습하는 FC Layer, hidden_dim 입력)
        self.fc = nn.Linear(hidden_dim, num_classes)  # (최종 context 벡터를 분류하는 FC Layer)

    def forward(self, x):
        embedded = self.embedding(x)  # (batch, seq_len, embed_dim)
        output, hidden = self.rnn(embedded)  # (batch, seq_len, hidden_dim)

        # 스코어 계산
        score = torch.tanh(self.attn_fc(output))  # (output을 attention layer에 통과)
        score = torch.sum(score, dim=2)  # (hidden_dim 차원 축소, dim=2)

        # softmax로 가중치 계산
        attn_weights = F.softmax(score, dim=1).unsqueeze(-1)  # (시퀀스 차원에 대해 softmax 적용, dim=1)

        # 가중합
        context = output * attn_weights  # (batch, seq_len, hidden_dim)
        context = torch.sum(context, dim=1)  # (타임스텝 차원을 축소하여 문장 단위 벡터 얻기, dim=1)

        logits = self.fc(context)  # (context 벡터를 FC Layer에 입력하여 예측)
        return logits

# %%
############################
# 6. 학습 / 평가 루프 정의
############################

def train_model(model, train_loader, val_loader=None, epochs=5, lr=0.001):
    model.to(device)
    optimizer = optim.Adam(model.parameters(), lr=lr)
    criterion = nn.CrossEntropyLoss()

    train_losses = []
    val_accuracies = []

    for epoch in range(1, epochs+1):
        model.train()
        running_loss = 0.0

        for i, (inputs, labels) in enumerate(train_loader):
            inputs = inputs.to(device)      # (batch, seq_len)
            labels = labels.squeeze().to(device)  # (batch)

            optimizer.zero_grad()
            outputs = model(inputs)         # (batch, num_classes)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        # 에폭별 평균 로스
        epoch_loss = running_loss / len(train_loader)
        train_losses.append(epoch_loss)

        # 검증 정확도(옵션)
        if val_loader is not None:
            acc = evaluate_model(model, val_loader)
            val_accuracies.append(acc)
            print(f"[Epoch {epoch}] Train Loss: {epoch_loss:.4f}, Val Acc: {acc*100:.2f}%")
        else:
            print(f"[Epoch {epoch}] Train Loss: {epoch_loss:.4f}")

    return train_losses, val_accuracies

def evaluate_model(model, data_loader):
    model.eval()
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for (inputs, labels) in data_loader:
            inputs = inputs.to(device)
            labels = labels.squeeze().to(device)

            outputs = model(inputs)
            preds = torch.argmax(outputs, dim=1)

            all_preds.extend(preds.cpu().numpy().tolist())
            all_labels.extend(labels.cpu().numpy().tolist())

    acc = accuracy_score(all_labels, all_preds)
    return acc

def plot_training_curve(train_losses, val_accuracies=None, title="Training Curve"):
    plt.figure(figsize=(10,4))

    # 학습 손실 곡선
    plt.subplot(1,2,1)
    plt.plot(train_losses, label='Train Loss')
    plt.title("Train Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()

    # 검증 정확도 곡선
    if val_accuracies is not None and len(val_accuracies) > 0:
        plt.subplot(1,2,2)
        plt.plot(val_accuracies, label='Val Acc', color='orange')
        plt.title("Validation Accuracy")
        plt.xlabel("Epoch")
        plt.ylabel("Accuracy")
        plt.legend()

    plt.suptitle(title)
    plt.show()

# %%
############################
# 7. 데이터 분할(Train/Valid) 준비
############################

# 여기서는 별도의 Validation 세트를 만들지 않고,
# 주어진 test_data_raw를 최종 테스트 용도로만 사용할 수도 있음.
# 하지만 간단히 train_data_raw를 다시 train/val로 나누는 방법 시연.

from sklearn.model_selection import train_test_split

# 현재 full_data (N=20000) 중 80%: train, 20%: val
train_subset, val_subset = train_test_split(full_data, test_size=0.2, random_state=42)

train_dataset_2 = NSMCDataset(train_subset, word2idx, max_len)
val_dataset_2   = NSMCDataset(val_subset, word2idx, max_len)

train_loader_2 = DataLoader(train_dataset_2, batch_size=batch_size, shuffle=True)
val_loader_2   = DataLoader(val_dataset_2, batch_size=batch_size, shuffle=False)

print(f"Train subset: {len(train_subset)}, Val subset: {len(val_subset)}")
# Out:
# Train subset: 16000, Val subset: 4000

# %%
############################
# 8. 모델별 학습 & 평가
############################

embed_dim = 128
hidden_dim = 128
num_classes = 2
EPOCHS = 20 # 유동적으로 조절하세요
LR = 0.001

# --- 8-1. RNN ---
print("========= RNN Training =========")
rnn_model = RNNClassifier(len(vocab), embed_dim, hidden_dim, num_classes)
rnn_train_losses, rnn_val_accs = train_model(rnn_model, train_loader_2, val_loader_2, epochs=EPOCHS, lr=LR)
plot_training_curve(rnn_train_losses, rnn_val_accs, title="RNN")

# 최종 테스트 세트 정확도
rnn_test_acc = evaluate_model(rnn_model, test_loader)
print(f"RNN Test Accuracy: {rnn_test_acc*100:.2f}%\n")

# --- 8-2. LSTM ---
print("========= LSTM Training =========")
lstm_model = LSTMClassifier(len(vocab), embed_dim, hidden_dim, num_classes)
lstm_train_losses, lstm_val_accs = train_model(lstm_model, train_loader_2, val_loader_2, epochs=EPOCHS, lr=LR)
plot_training_curve(lstm_train_losses, lstm_val_accs, title="LSTM")

# 최종 테스트 세트 정확도
lstm_test_acc = evaluate_model(lstm_model, test_loader)
print(f"LSTM Test Accuracy: {lstm_test_acc*100:.2f}%\n")

# --- 8-3. RNN + Attention ---
print("========= RNN + Attention Training =========")
attn_model = RNNWithAttention(len(vocab), embed_dim, hidden_dim, num_classes)
attn_train_losses, attn_val_accs = train_model(attn_model, train_loader_2, val_loader_2, epochs=EPOCHS, lr=LR)
plot_training_curve(attn_train_losses, attn_val_accs, title="RNN+Attention")

# 최종 테스트 세트 정확도
attn_test_acc = evaluate_model(attn_model, test_loader)
print(f"RNN+Attention Test Accuracy: {attn_test_acc*100:.2f}%\n")
# Out:
# ========= RNN Training =========
# [Epoch 1] Train Loss: 0.6997, Val Acc: 48.93%
# [Epoch 2] Train Loss: 0.6909, Val Acc: 49.08%
# [Epoch 3] Train Loss: 0.6794, Val Acc: 51.18%
# [Epoch 4] Train Loss: 0.6624, Val Acc: 51.42%
# [Epoch 5] Train Loss: 0.6465, Val Acc: 51.02%
# [Epoch 6] Train Loss: 0.6433, Val Acc: 48.83%
# [Epoch 7] Train Loss: 0.6275, Val Acc: 49.40%
# [Epoch 8] Train Loss: 0.6209, Val Acc: 49.10%
# [Epoch 9] Train Loss: 0.6208, Val Acc: 49.20%
# [Epoch 10] Train Loss: 0.6184, Val Acc: 49.28%
# [Epoch 11] Train Loss: 0.6200, Val Acc: 49.98%
# [Epoch 12] Train Loss: 0.6186, Val Acc: 51.65%
# [Epoch 13] Train Loss: 0.6081, Val Acc: 51.70%
# [Epoch 14] Train Loss: 0.6100, Val Acc: 49.18%
# [Epoch 15] Train Loss: 0.6072, Val Acc: 52.75%
# [Epoch 16] Train Loss: 0.5966, Val Acc: 53.27%
# [Epoch 17] Train Loss: 0.5940, Val Acc: 52.90%
# [Epoch 18] Train Loss: 0.5947, Val Acc: 52.35%
# [Epoch 19] Train Loss: 0.5826, Val Acc: 53.70%
# [Epoch 20] Train Loss: 0.5881, Val Acc: 51.23%
# RNN Test Accuracy: 52.43%
#
# ========= LSTM Training =========
# [Epoch 1] Train Loss: 0.6945, Val Acc: 51.82%
# [Epoch 2] Train Loss: 0.6478, Val Acc: 72.97%
# [Epoch 3] Train Loss: 0.4687, Val Acc: 77.12%
# [Epoch 4] Train Loss: 0.3507, Val Acc: 78.67%
# [Epoch 5] Train Loss: 0.2627, Val Acc: 78.70%
# [Epoch 6] Train Loss: 0.1861, Val Acc: 78.90%
# [Epoch 7] Train Loss: 0.1250, Val Acc: 79.30%
# [Epoch 8] Train Loss: 0.0940, Val Acc: 78.80%
# [Epoch 9] Train Loss: 0.0674, Val Acc: 78.75%
# [Epoch 10] Train Loss: 0.0517, Val Acc: 78.70%
# [Epoch 11] Train Loss: 0.0480, Val Acc: 79.17%
# [Epoch 12] Train Loss: 0.0421, Val Acc: 78.35%
# [Epoch 13] Train Loss: 0.0286, Val Acc: 78.92%
# [Epoch 14] Train Loss: 0.0286, Val Acc: 78.88%
# [Epoch 15] Train Loss: 0.0240, Val Acc: 78.70%
# [Epoch 16] Train Loss: 0.0255, Val Acc: 77.72%
# [Epoch 17] Train Loss: 0.0329, Val Acc: 78.30%
# [Epoch 18] Train Loss: 0.0241, Val Acc: 78.15%
# [Epoch 19] Train Loss: 0.0197, Val Acc: 78.17%
# [Epoch 20] Train Loss: 0.0233, Val Acc: 77.78%
# LSTM Test Accuracy: 77.62%
#
# ========= RNN + Attention Training =========
# [Epoch 1] Train Loss: 0.6156, Val Acc: 71.75%
# [Epoch 2] Train Loss: 0.4763, Val Acc: 76.30%
# [Epoch 3] Train Loss: 0.3870, Val Acc: 79.12%
# [Epoch 4] Train Loss: 0.3226, Val Acc: 79.15%
# [Epoch 5] Train Loss: 0.2669, Val Acc: 79.03%
# [Epoch 6] Train Loss: 0.2132, Val Acc: 78.65%
# [Epoch 7] Train Loss: 0.1659, Val Acc: 78.50%
# [Epoch 8] Train Loss: 0.1248, Val Acc: 78.35%
# [Epoch 9] Train Loss: 0.0922, Val Acc: 77.83%
# [Epoch 10] Train Loss: 0.0665, Val Acc: 77.33%
# [Epoch 11] Train Loss: 0.0544, Val Acc: 77.58%
# [Epoch 12] Train Loss: 0.0427, Val Acc: 77.38%
# [Epoch 13] Train Loss: 0.0407, Val Acc: 76.83%
# [Epoch 14] Train Loss: 0.0335, Val Acc: 76.98%
# [Epoch 15] Train Loss: 0.0333, Val Acc: 77.45%
# [Epoch 16] Train Loss: 0.0253, Val Acc: 77.10%
# [Epoch 17] Train Loss: 0.0234, Val Acc: 77.15%
# [Epoch 18] Train Loss: 0.0234, Val Acc: 76.60%
# [Epoch 19] Train Loss: 0.0307, Val Acc: 77.40%
# [Epoch 20] Train Loss: 0.0230, Val Acc: 77.15%
# RNN+Attention Test Accuracy: 77.64%

# %%
############################
# 9. 혼동 행렬(Confusion Matrix) 시각화
############################

def plot_confusion_matrix(model, data_loader, title="Confusion Matrix"):
    model.eval()
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for (inputs, labels) in data_loader:
            inputs = inputs.to(device)
            labels = labels.squeeze().to(device)

            outputs = model(inputs)
            preds = torch.argmax(outputs, dim=1)

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    cm = confusion_matrix(all_labels, all_preds)
    plt.figure(figsize=(5,4))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
    plt.title(title)
    plt.xlabel("Predicted")
    plt.ylabel("True")
    plt.show()

print("=== Confusion Matrix: RNN ===")
plot_confusion_matrix(rnn_model, test_loader, title="RNN Confusion Matrix")

print("=== Confusion Matrix: LSTM ===")
plot_confusion_matrix(lstm_model, test_loader, title="LSTM Confusion Matrix")

print("=== Confusion Matrix: RNN+Attention ===")
plot_confusion_matrix(attn_model, test_loader, title="RNN+Attention Confusion Matrix")
# Out:
# === Confusion Matrix: RNN ===
# === Confusion Matrix: LSTM ===
# === Confusion Matrix: RNN+Attention ===

# %%
import torch
import torch.nn.functional as F

# 문장을 모델이 예측할 수 있도록 변환하고 감정 분석 수행
def predict_sentiment(model, sentence, word2idx, max_len=30):
    """
    감정 분석을 수행하는 함수 (입력 문장을 숫자 토큰으로 변환 후 모델에 입력)
    """
    model.eval()
    tokens = tokenize(sentence)  # 형태소 분석 및 토큰화
    token_ids = [word2idx.get(tok, word2idx["<unk>"]) for tok in tokens]  # 단어를 ID로 변환
    token_ids = pad_sequences(token_ids, max_len)  # 패딩 적용

    input_tensor = torch.LongTensor(token_ids).unsqueeze(0).to(device)  # (1, seq_len)

    with torch.no_grad():
        output = model(input_tensor)  # 모델 예측
        probs = F.softmax(output, dim=1)  # 확률 값
        pred_label = torch.argmax(probs, dim=1).item()  # 예측 라벨 (0: 부정, 1: 긍정)

    return pred_label, probs.squeeze().cpu().numpy()

# %%
# 예측 함수: 3개 모델 모두 실행
def predict_with_all_models(sentence):
    """
    사용자 입력 문장에 대해 RNN, LSTM, RNN+Attention 모델이 각각 어떻게 예측하는지 출력
    """
    print("\n💬 입력 문장:", sentence)
    print("=" * 50)

    models = {
        "RNN": rnn_model,
        "LSTM": lstm_model,
        "RNN+Attention": attn_model
    }

    for model_name, model in models.items():
        label, probs = predict_sentiment(model, sentence, word2idx)
        sentiment = "긍정 😊" if label == 1 else "부정 😡"

        print(f"🧠 [{model_name} 모델]")
        print(f"🔍 예측 감정: {sentiment}")
        print(f"📊 확률: 부정 {probs[0]:.4f} | 긍정 {probs[1]:.4f}")
        print("-" * 50)

# 사용자 입력 받기
sample_sentence = input("문장을 입력하세요: ")
predict_with_all_models(sample_sentence)
# Out:
# 문장을 입력하세요: 이 얼마나 아름다운 날인가!
#
# 💬 입력 문장: 이 얼마나 아름다운 날인가!
# ==================================================
# 🧠 [RNN 모델]
# 🔍 예측 감정: 긍정 😊
# 📊 확률: 부정 0.3958 | 긍정 0.6042
# --------------------------------------------------
# 🧠 [LSTM 모델]
# 🔍 예측 감정: 긍정 😊
# 📊 확률: 부정 0.0002 | 긍정 0.9998
# --------------------------------------------------
# 🧠 [RNN+Attention 모델]
# 🔍 예측 감정: 긍정 😊
# 📊 확률: 부정 0.0000 | 긍정 1.0000
# --------------------------------------------------
